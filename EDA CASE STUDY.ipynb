# %% [markdown]
# # **Dataset link** :
#
# https://drive.google.com/file/d/1Uzz8t8IbCoGCSNadaLe0fkZX6efU8WC6/view?usp=sharing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/insurance (2).csv')

# %%
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
# i want to see the full dataset

print(df.to_string())
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  Anual_Salary     region       charges
# 0     18.0    male  23.210       0.0     no  29087.543130                17.0      715428.0          4.720921e+06                              0.0  5.578497e+07  southeast   1121.873900
# 1     18.0    male  30.140       0.0     no  39053.674370                 7.0      699157.0          4.329832e+06                              0.0  1.370089e+07  southeast   1131.506600
# 2     18.0    male  33.330       0.0     no  39023.627590                19.0      702341.0          6.884861e+06                              0.0  7.352311e+07  southeast   1135.940700
# 3     18.0    male  33.660       0.0     no  28185.393320                11.0      700250.0          4.274774e+06                              0.0  7.581968e+07  southeast   1136.399400
# ...

# %%
# show the columns names

df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
# rows and column

df.shape
# Out:
# (1338, 13)

# %%
# checking the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
# how to handle null values ??

# string data: mode

# numerical data : mean/ median



for col in df.columns:
  if df[col].dtypes != 'object':
      df[col] =df[col].fillna(df[col].mean())

  else:
     df[col] =df[col].fillna(df[col].mode())

# %%
df.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1338 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1338 non-null   float64
#  3   children                         1338 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1338 non-null   float64
#  6   past_consultations               1338 non-null   float64
#  7   num_of_steps                     1338 non-null   float64
#  8   Hospital_expenditure             1338 non-null   float64
#  9   NUmber_of_past_hospitalizations  1338 non-null   float64
#  10  Anual_Salary                     1338 non-null   float64
# ...

# %%
df['age'] = df['age'].astype('int')

# %%
# converting the data of age from float to integer

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1338 non-null   int64
#  1   sex                              1338 non-null   object
#  2   bmi                              1338 non-null   float64
#  3   children                         1338 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1338 non-null   float64
#  6   past_consultations               1338 non-null   float64
#  7   num_of_steps                     1338 non-null   float64
#  8   Hospital_expenditure             1338 non-null   float64
#  9   NUmber_of_past_hospitalizations  1338 non-null   float64
#  10  Anual_Salary                     1338 non-null   float64
#  11  region                           1338 non-null   object
# ...

# %%
# checking for duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # outlier analysis

# %%
plt.figure(figsize = (6,5))
sns.boxplot(df['age'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3649709066.py in <cell line: 0>()
#       1 plt.figure(figsize = (6,5))
# ----> 2 sns.boxplot(df['age'])
#       3 plt.show()
#
# NameError: name 'df' is not defined

# %%
for  i in df.columns:
  if df[i].dtypes == 'int64' or df[i].dtypes == 'float64':
    plt.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
for i in df.columns:
  if df[i].dtypes == 'int64' or df[i].dtypes =='float64':
    q1 = df[i].quantile(0.25)
    q3 = df[i].quantile(0.75)
    iqr = q3 -q1

    upper_fence = q3+1.5*iqr
    lower_fence = q1 -1.5*iqr

    df = df[(df[i] >= lower_fence) &(df[i]<= upper_fence)]

# %%
for  i in df.columns:
  if df[i].dtypes == 'int64' or df[i].dtypes == 'float64':
    plt.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
df['NUmber_of_past_hospitalizations']
# Out:
# 151     1.0
# 152     1.0
# 153     1.0
# 154     1.0
# 155     1.0
#        ...
# 1046    1.0
# 1048    1.0
# 1050    1.0
# 1062    1.0
# 1069    1.0
# Name: NUmber_of_past_hospitalizations, Length: 881, dtype: float64

# %%
# distribution plot for all numerical columns :


import warnings
warnings.filterwarnings('ignore')
for i in df.columns:
  if df[i].dtype == 'int64' or df[i].dtype == 'float64':
    sns.distplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
# heatmap for checking the correlation
plt.figure(figsize = (10,5))
numeric_data = df.select_dtypes(include =['int64', 'float64'])

sns.heatmap(numeric_data.corr(), annot=True)
# Out:
# <Axes: >

# %%
numCol=df.select_dtypes(include=['int64' ,'float64'])
correlation=numCol.corr()
sns.heatmap(correlation,annot=True,cmap='plasma')
# Out:
# <Axes: >

# %%
# average charges by smoker status

# average charges by region

# average bmi by sex

# 5mins
df.groupby(['smoker', 'region'])['charges'].mean()
# Out:
# smoker  region
# no      northeast     8506.160934
#         northwest     7945.209776
#         southeast     8085.553542
#         southwest     8237.594233
# yes     northeast    15805.695507
#         northwest    17042.198172
#         southeast    17961.193245
#         southwest    16905.947400
# Name: charges, dtype: float64

# %%
df.groupby('sex')['bmi'].mean()
# Out:
# sex
# female    30.062585
# male      30.530734
# Name: bmi, dtype: float64

# %%
# count number of people in each region
df['region'].value_counts()
# Out:
# region
# northwest    229
# southwest    224
# northeast    221
# southeast    207
# Name: count, dtype: int64

# %%
# show the distribution of charges for smoker or non smoker
sns.boxplot(x = 'smoker', y ='charges' , data = df)
plt.title('charges distribution by smoking status')
plt.show()

# %%
sns.displot(data  = df, x ='smoker', y ='charges', hue ='smoker')

plt.show()

# %%
# top 5 highest paying  customer

# which gender and smoker combinatio has the highest average insurance charges

# create a new bmi category column

# if bmi < 18.5 :  underweight

# if 18.5 - 24.9 -> normal

#  30+ obese
